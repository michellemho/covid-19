# %%
import pysal
import pandas as pd
import numpy as np
import libpysal as ps
import geopandas as gp
from mgwr.gwr import GWR
from mgwr.sel_bw import Sel_BW
from spglm.family import Gaussian, Binomial
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Saturday Dinner.csv')

# %%
df.head()
# Out:
#    shapeId shapeType  shapeLabel  pointX  pointY  positive  days_to_positive  \
# 0        7     point           2     394     877         1               4.0
# 1       31     point           3    1485     415         0               NaN
# 2       10     point           4     122     272         1               4.0
# 3       13     point           5     396     206         1               3.0
# 4       30     point           6    1599     900         0               NaN
#
#    days_to_symptoms  days_since_last_vax last_vax_date Fri General Bkft  \
# 0               4.0                 64.0        4/1/22              NaN
# 1               NaN                  NaN           NaN              NaN
# 2               2.0                 24.0       5/11/22                N
# 3               3.0                 66.0       3/30/22                Y
# 4               NaN                  NaN           NaN              NaN
#
#   Fri Ldrshp Bkft Fri Sem Fri Lun Fri Din Sat Pic
# 0               Y       Y       Y       N       N
# 1             NaN     NaN     NaN     NaN     NaN
# 2             NaN       N       N       N       N
# 3             NaN       Y       Y       Y       N
# 4             NaN     NaN     NaN     NaN     NaN

# %%
coords = df[['pointX', 'pointY']]

# %%
y = df['positive']
X = df[['days_since_last_vax', 'Fri General Bkft', 'Fri Ldrshp Bkft', 'Fri Sem', 'Fri Lun', 'Fri Din', 'Sat Pic']]

# %%
# fill missing values with average or "N" for no attendance...
X['days_since_last_vax'] = X['days_since_last_vax'].fillna(X['days_since_last_vax'].mean())
X[['Fri General Bkft', 'Fri Ldrshp Bkft', 'Fri Sem', 'Fri Lun', 'Fri Din', 'Sat Pic']] = X[['Fri General Bkft', 'Fri Ldrshp Bkft', 'Fri Sem', 'Fri Lun', 'Fri Din', 'Sat Pic']].fillna('N').eq('Y').mul(1)
# Out:
# /var/folders/7x/hblyd2c174x6wg_bc64fg0lh0000gp/T/ipykernel_54233/3686021259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['days_since_last_vax'] = X['days_since_last_vax'].fillna(X['days_since_last_vax'].mean())
# /var/folders/7x/hblyd2c174x6wg_bc64fg0lh0000gp/T/ipykernel_54233/3686021259.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[['Fri General Bkft', 'Fri Ldrshp Bkft', 'Fri Sem', 'Fri Lun', 'Fri Din', 'Sat Pic']] = X[['Fri General Bkft', 'Fri Ldrshp Bkft', 'Fri Sem', 'Fri Lun', 'Fri Din', 'Sat Pic']].fillna('N').eq('Y').mul(1)

# %%
X
# Out:
#     days_since_last_vax  Fri General Bkft  Fri Ldrshp Bkft  Fri Sem  Fri Lun  \
# 0                  64.0                 0                1        1        1
# 1                  48.0                 0                0        0        0
# 2                  24.0                 0                0        0        0
# 3                  66.0                 1                0        1        1
# 4                  48.0                 0                0        0        0
# 5                  48.0                 0                0        0        0
# 6                  57.0                 0                0        1        1
# 7                  48.0                 0                0        0        0
# 8                  48.0                 0                0        0        0
# 9                  48.0                 0                0        0        0
# 10                 40.0                 0                1        1        1
# 11                 48.0                 0                0        0        0
# 12                 48.0                 0                0        0        0
# 13                 48.0                 0                0        0        1
# 14                 63.0                 0                0        1        1
# 15                 48.0                 0                0        0        0
# 16                 48.0                 0                0        0        0
# 17                 34.0                 0                0        0        1
# 18                 65.0                 1                0        1        1
# 19                 48.0                 0                0        1        1
# 20                 64.0                 1                0        1        1
# 21                 22.0                 0                0        0        0
# 22                 48.0                 0                1        1        1
# 23                 43.0                 0                1        1        1
# 24                 21.0                 0                0        0        1
# 25                 48.0                 0                0        0        0
# 26                 31.0                 0                0        0        0
# 27                 15.0                 0                0        0        1
# 28                 48.0                 0                0        0        0
# 29                 48.0                 0                0        0        0
# 30                 48.0                 0                0        0        0
# 31                 48.0                 0                0        0        0
# 32                 34.0                 0                0        0        1
# 33                 56.0                 1                0        1        1
# 34                 48.0                 0                0        0        0
# 35                 48.0                 0                0        0        0
# 36                 64.0                 0                0        0        0
# 37                 48.0                 0                0        0        0
# 38                 48.0                 0                0        0        1
# 39                 48.0                 1                0        1        1
# 40                133.0                 0                1        1        1
# 41                 16.0                 0                1        1        1
# 42                 48.0                 1                0        1        1
# 43                 48.0                 0                0        0        0
# 44                 48.0                 0                0        0        0
# 45                 48.0                 0                0        0        0
# 46                 48.0                 0                0        0        0
#
#     Fri Din  Sat Pic
# 0         0        0
# 1         0        0
# 2         0        0
# 3         1        0
# 4         0        0
# 5         0        0
# 6         1        0
# 7         0        0
# 8         0        0
# 9         0        0
# 10        1        0
# 11        0        0
# 12        1        0
# 13        1        0
# 14        1        0
# 15        0        0
# 16        0        0
# 17        1        0
# 18        1        0
# 19        1        1
# 20        1        1
# 21        1        1
# 22        1        1
# 23        1        1
# 24        1        0
# 25        0        0
# 26        1        1
# 27        1        0
# 28        0        0
# 29        0        0
# 30        1        0
# 31        0        0
# 32        1        1
# 33        1        0
# 34        0        0
# 35        0        0
# 36        1        1
# 37        0        0
# 38        1        0
# 39        0        0
# 40        0        1
# 41        1        0
# 42        1        0
# 43        0        0
# 44        0        0
# 45        0        0
# 46        0        0

# %%
# Logistic Regression Model (NO SPATIAL COORDINATES)
model = LogisticRegression(solver='liblinear', random_state=42).fit(X, y)

# %%
model.score(X, y)
# Out:
# 0.9148936170212766

# %%
cm = confusion_matrix(y, model.predict(X))

fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0, 1), ticklabels=('Predicted 0s', 'Predicted 1s'))
ax.yaxis.set(ticks=(0, 1), ticklabels=('Actual 0s', 'Actual 1s'))
ax.set_ylim(1.5, -0.5)
for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i, j], ha='center', va='center', color='red')
plt.show()

# %% [markdown]
# This logistic model was able to fit the data with high accuracy... unfortunately there's a lack of attendance information for attendees who did not report testing positive. I made the (probably inaccurate) assumption that they did not attend previous sessions and that their days-since-last-vaccine was the average. This missing-data imputation is probably the cause for such a highly accurate model.

# %%
# Geographically Weighted Regression

# %%
coords_list = list(zip(coords['pointX'], coords['pointY']))

# %%
y_reshape = np.array(y).reshape((-1,1))
X_reshape = np.array(X)

# %%
model_gwr = GWR(coords_list, y_reshape, X_reshape, bw=30)
results = model_gwr.fit()
print(results.params.shape)
# Out:
# (47, 8)
# /Users/michelle.ho/.virtualenvs/covid19/lib/python3.8/site-packages/spglm/iwls.py:37: LinAlgWarning: Ill-conditioned matrix (rcond=2.89493e-19): result may not be accurate.
#   xtx_inv_xt = linalg.solve(xtx, xT)
# /Users/michelle.ho/.virtualenvs/covid19/lib/python3.8/site-packages/spglm/iwls.py:37: LinAlgWarning: Ill-conditioned matrix (rcond=2.76744e-19): result may not be accurate.
#   xtx_inv_xt = linalg.solve(xtx, xT)

# %%
results.summary()
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                  47
# Number of covariates:                                                     8
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                              2.628
# Log-likelihood:                                                       1.082
# AIC:                                                                 13.836
# AICc:                                                                20.700
# BIC:                                                               -147.528
# R2:                                                                   0.775
# Adj. R2:                                                              0.735
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                   0.113      0.143      0.786      0.432
# X1                                  -0.000      0.003     -0.083      0.934
# X2                                   0.131      0.185      0.709      0.478
# X3                                   0.118      0.191      0.618      0.536
# X4                                   0.791      0.193      4.099      0.000
# X5                                  -0.483      0.148     -3.258      0.001
# X6                                   0.497      0.126      3.939      0.000
# X7                                   0.287      0.117      2.459      0.014
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      30.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                              0.974
# Effective number of parameters (trace(S)):                           19.693
# Degree of freedom (n - trace(S)):                                    27.307
# Sigma estimate:                                                       0.189
# Log-likelihood:                                                      24.400
# AIC:                                                                 -7.415
# AICc:                                                                28.060
# BIC:                                                                 30.870
# R2:                                                                   0.917
# Adjusted R2:                                                          0.854
# Adj. alpha (95%):                                                     0.020
# Adj. critical t value (95%):                                          2.404
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                        0.164      0.151     -0.128      0.187      0.390
# X1                       -0.003      0.003     -0.007     -0.004      0.003
# X2                       -0.031      0.066     -0.208     -0.029      0.081
# X3                       -0.135      0.173     -0.553     -0.127      0.162
# X4                        0.923      0.184      0.679      0.880      1.235
# X5                       -0.387      0.316     -0.790     -0.582      0.227
# X6                        0.431      0.478     -0.234      0.815      0.924
# X7                        0.269      0.111      0.175      0.211      0.574
# ===========================================================================

# %%
scale = results.scale
residuals = results.resid_response

pred_results = model.predict(coords, X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [304], in <cell line: 4>()
#       1 scale = results.scale
#       2 residuals = results.resid_response
# ----> 4 pred_results = model.predict(coords, X)
#
# TypeError: predict() takes 2 positional arguments but 3 were given

# %%
model_gwr.predict(coords, X)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [305], in <cell line: 1>()
# ----> 1 model_gwr.predict(coords, X)
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/mgwr/gwr.py:397, in GWR.predict(self, points, P, exog_scale, exog_resid, fit_params)
#     395 else:
#     396     self.P = P
# --> 397 gwr = self.fit(**fit_params)
#     399 return gwr
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/mgwr/gwr.py:335, in GWR.fit(self, ini_params, tol, max_iter, solve, lite, pool)
#     332 else:
#     333     rslt = map(self._local_fit, range(m))  #sequential
# --> 335 rslt_list = list(zip(*rslt))
#     336 influ = np.array(rslt_list[0]).reshape(-1, 1)
#     337 resid = np.array(rslt_list[1]).reshape(-1, 1)
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/mgwr/gwr.py:248, in GWR._local_fit(self, i)
#     244 def _local_fit(self, i):
#     245     """
#     246     Local fitting at location i.
#     247     """
# --> 248     wi = self._build_wi(i, self.bw).reshape(-1, 1)  #local spatial weights
#     250     if isinstance(self.family, Gaussian):
#     251         betas, inv_xtx_xt = _compute_betas_gwr(self.y, self.X, wi)
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/mgwr/gwr.py:236, in GWR._build_wi(self, i, bw)
#     233 def _build_wi(self, i, bw):
#     235     try:
# --> 236         wi = Kernel(i, self.coords, bw, fixed=self.fixed,
#     237                     function=self.kernel, points=self.points,
#     238                     spherical=self.spherical).kernel
#     239     except BaseException:
#     240         raise  # TypeError('Unsupported kernel function  ', kernel)
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/mgwr/kernels.py:49, in Kernel.__init__(self, i, data, bw, fixed, function, eps, ids, points, spherical)
#      47     self.dvec = local_cdist(data[i], data, spherical).reshape(-1)
#      48 else:
# ---> 49     self.dvec = local_cdist(points[i], data, spherical).reshape(-1)
#      51 self.function = function.lower()
#      53 if fixed:
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 0

# %%
cm = confusion_matrix(y, model_gwr.predict(coords, X))

fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0, 1), ticklabels=('Predicted 0s', 'Predicted 1s'))
ax.yaxis.set(ticks=(0, 1), ticklabels=('Actual 0s', 'Actual 1s'))
ax.set_ylim(1.5, -0.5)
for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i, j], ha='center', va='center', color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [306], in <cell line: 1>()
# ----> 1 cm = confusion_matrix(y, model_gwr.predict(coords, X))
#       3 fig, ax = plt.subplots(figsize=(8, 8))
#       4 ax.imshow(cm)
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/mgwr/gwr.py:382, in GWR.predict(self, points, P, exog_scale, exog_resid, fit_params)
#     357 """
#     358 Method that predicts values of the dependent variable at un-sampled
#     359 locations
#    (...)
#     379
#     380 """
#     381 if (exog_scale is None) & (exog_resid is None):
# --> 382     train_gwr = self.fit(**fit_params)
#     383     self.exog_scale = train_gwr.scale
#     384     self.exog_resid = train_gwr.resid_response
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/mgwr/gwr.py:335, in GWR.fit(self, ini_params, tol, max_iter, solve, lite, pool)
#     332 else:
#     333     rslt = map(self._local_fit, range(m))  #sequential
# --> 335 rslt_list = list(zip(*rslt))
#     336 influ = np.array(rslt_list[0]).reshape(-1, 1)
#     337 resid = np.array(rslt_list[1]).reshape(-1, 1)
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/mgwr/gwr.py:248, in GWR._local_fit(self, i)
#     244 def _local_fit(self, i):
#     245     """
#     246     Local fitting at location i.
#     247     """
# --> 248     wi = self._build_wi(i, self.bw).reshape(-1, 1)  #local spatial weights
#     250     if isinstance(self.family, Gaussian):
#     251         betas, inv_xtx_xt = _compute_betas_gwr(self.y, self.X, wi)
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/mgwr/gwr.py:236, in GWR._build_wi(self, i, bw)
#     233 def _build_wi(self, i, bw):
#     235     try:
# --> 236         wi = Kernel(i, self.coords, bw, fixed=self.fixed,
#     237                     function=self.kernel, points=self.points,
#     238                     spherical=self.spherical).kernel
#     239     except BaseException:
#     240         raise  # TypeError('Unsupported kernel function  ', kernel)
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/mgwr/kernels.py:49, in Kernel.__init__(self, i, data, bw, fixed, function, eps, ids, points, spherical)
#      47     self.dvec = local_cdist(data[i], data, spherical).reshape(-1)
#      48 else:
# ---> 49     self.dvec = local_cdist(points[i], data, spherical).reshape(-1)
#      51 self.function = function.lower()
#      53 if fixed:
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.virtualenvs/covid19/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 0

# %%
georgia = gp.read_file(ps.examples.get_path('G_utm.shp'))

#Prepare Georgia dataset inputs
y = georgia['PctBach'].values.reshape((-1,1))
X = georgia[['PctFB', 'PctBlack', 'PctRural']].values
u = georgia['X']
v = georgia['Y']
coords = list(zip(u,v))

np.random.seed(908)
sample = np.random.choice(range(47), 10)
mask = np.ones_like(y,dtype=bool).flatten()
mask[sample] = False

cal_coords = coords[mask]
cal_y = y[mask]
cal_X = X[mask]

pred_coords = coords[~mask]
pred_y = y[~mask]
pred_X = X[~mask]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [328], in <cell line: 15>()
#      12 mask = np.ones_like(y,dtype=bool).flatten()
#      13 mask[sample] = False
# ---> 15 cal_coords = coords[mask]
#      16 cal_y = y[mask]
#      17 cal_X = X[mask]
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
coords
# Out:
# [(941396.6, 3521764),
#  (895553.0, 3471916),
#  (930946.4, 3502787),
#  (745398.6, 3474765),
#  (849431.3, 3665553),
#  (819317.3, 3807616),
#  (803747.1, 3769623),
#  (699011.5, 3793408),
#  (863020.8, 3520432),
#  (859915.8, 3466377),
#  (809736.9, 3636468),
#  (844270.1, 3595691),
#  (979288.9, 3463849),
#  (827822.0, 3421638),
#  (1023145.0, 3554982),
#  (994903.4, 3600493),
#  (971593.8, 3671394),
#  (782448.2, 3684504),
#  (724741.2, 3492653),
#  (1008480.0, 3437933),
#  (964264.9, 3598842),
#  (678778.6, 3713250),
#  (670055.9, 3862318),
#  (962612.3, 3432769),
#  (1059706.0, 3556747),
#  (704959.2, 3577608),
#  (653026.6, 3813760),
#  (734240.9, 3794110),
#  (832508.6, 3762905),
#  (695793.9, 3495219),
#  (745538.8, 3711726),
#  (908046.1, 3428340),
#  (724646.8, 3757187),
#  (894463.9, 3492465),
#  (808691.8, 3455994),
#  (942527.9, 3722100),
#  (839816.1, 3449007),
#  (705457.9, 3694344),
#  (783416.5, 3623343),
